# %%
print("aaaa")
print("bbbb")

# %% [markdown]
# ### title
# fdafdsa
# $f(x) = 3x + 7 $

# %% [markdown]
# ### title
# fdafdsa
#
# $f(x) = 3x + 7 $

# %%
class A:
  def __init__(self):
    self.aa = 0

# %%
a = A()
print(hasattr(a, "aa"))
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.random.randn(300)
plt.plot(x, "r--o")
